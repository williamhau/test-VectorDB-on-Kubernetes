# %%
# %pip install -U langchain-postgres psycopg[binary] pypdf sentence-transformers
# Out:
# Requirement already satisfied: langchain-postgres in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (0.0.17)
# Requirement already satisfied: pypdf in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (6.7.3)
# Collecting pypdf
#   Downloading pypdf-6.7.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: sentence-transformers in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (5.2.3)
# Requirement already satisfied: psycopg[binary] in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (3.3.3)
# Requirement already satisfied: asyncpg>=0.30.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-postgres) (0.31.0)
# Requirement already satisfied: langchain-core<2.0,>=0.2.13 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-postgres) (1.2.16)
# Requirement already satisfied: numpy<3,>=1.21 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-postgres) (2.4.2)
# Requirement already satisfied: pgvector<0.4,>=0.2.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-postgres) (0.3.6)
# Requirement already satisfied: psycopg-pool<4,>=3.2.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-postgres) (3.3.0)
# Requirement already satisfied: sqlalchemy<3,>=2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sqlalchemy[asyncio]<3,>=2->langchain-postgres) (2.0.47)
# Requirement already satisfied: typing-extensions>=4.6 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from psycopg[binary]) (4.15.0)
# Requirement already satisfied: psycopg-binary==3.3.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from psycopg[binary]) (3.3.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0,>=0.2.13->langchain-postgres) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0,>=0.2.13->langchain-postgres) (0.7.7)
# Requirement already satisfied: packaging>=23.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0,>=0.2.13->langchain-postgres) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0,>=0.2.13->langchain-postgres) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0,>=0.2.13->langchain-postgres) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0,>=0.2.13->langchain-postgres) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0,>=0.2.13->langchain-postgres) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=0.2.13->langchain-postgres) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (0.25.0)
# Requirement already satisfied: anyio in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (4.12.1)
# Requirement already satisfied: certifi in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (1.0.9)
# Requirement already satisfied: idna in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0,>=0.2.13->langchain-postgres) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0,>=0.2.13->langchain-postgres) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0,>=0.2.13->langchain-postgres) (0.4.2)
# Requirement already satisfied: greenlet>=1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sqlalchemy<3,>=2->sqlalchemy[asyncio]<3,>=2->langchain-postgres) (3.3.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (5.2.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: torch>=1.11.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: tqdm in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.19)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: shellingham in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=0.2.13->langchain-postgres) (2.6.3)
# Requirement already satisfied: setuptools in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=1.11.0->sentence-transformers) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: typer>=0.24.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Downloading pypdf-6.7.4-py3-none-any.whl (331 kB)
# Installing collected packages: pypdf
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 6.7.3
#     Uninstalling pypdf-6.7.3:
#       Successfully uninstalled pypdf-6.7.3
# Successfully installed pypdf-6.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import psycopg2
from datasets import load_dataset
from sentence_transformers import SentenceTransformer

from transformers import logging as transformers_logging
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD") 
print(POSTGRES_PASSWORD)
# Set transformers logging to error only
transformers_logging.set_verbosity_error()

# 1. Database & Extension Initialization
conn = psycopg2.connect(f"postgres://postgres:{POSTGRES_PASSWORD}@localhost:5432/postgres")
cur = conn.cursor()
cur.execute("CREATE EXTENSION IF NOT EXISTS vectorscale CASCADE;")

# 2. Optimized 2026 Trading Schema
# Using pgvectorscale's DiskANN for low-latency searches on SSD
cur.execute("""
    CREATE TABLE IF NOT EXISTS trading_signals (
        id SERIAL PRIMARY KEY,
        ticker TEXT,
        data_source TEXT,
        raw_text TEXT,
        embedding vector(384)
    );
""")

cur.execute("""
    CREATE INDEX IF NOT EXISTS idx_diskann_signals 
    ON trading_signals USING diskann (embedding vector_cosine_ops);
""")

# 3. Fetching Actual 2026 Market & Alternative Data
# A. Market Price Regime (Yahoo Finance)
ticker = "NVDA"
# NVIDIA remains a core AI-driven asset in Feb 2026 market rallies
hist = yf.Ticker(ticker).history(period="1d", interval="1m")
price_signal = f"Market Regime for {ticker} at {hist.index[-1]}: Price {hist['Close'].iloc[-1]:.2f}"

# B. Corporate Filings (SEC/Financial Reports in Parquet)
# We use a dataset known to have a valid Parquet export to avoid Script errors
sec_ds = load_dataset("HuggingFaceFW/finepdfs_100BT", split="train", streaming=True)
filing_sample = next(iter(sec_ds))['text'][:500]

# C. Social Alternative Data (Financial Sentiment)
# Many sentiment datasets have been converted to script-less Parquet
twit_ds = load_dataset("zeroshot/twitter-financial-news-sentiment", split="train", streaming=True)
tweet_sample = next(iter(twit_ds))['text']

# 4. Vectorization and Storage
model = SentenceTransformer('all-MiniLM-L6-v2')
sources = [("market", price_signal), ("filing", filing_sample), ("social", tweet_sample)]

for src, txt in sources:
    vec = model.encode(txt).tolist()
    cur.execute(
        "INSERT INTO trading_signals (ticker, data_source, raw_text, embedding) VALUES (%s, %s, %s, %s)",
        (ticker, src, txt, vec)
    )

# 5. Hedge Fund "Regime Detection" Query
# Identifying current market conditions that match historical risk factors
# 1. Prepare the query
query_text = "increased short interest in software stocks and AI margin compression"
query_vec = model.encode(query_text).tolist()

# 2. Execute with explicit casting (Solves UndefinedFunction error)
try:
    cur.execute("""
        SELECT 
            data_source, 
            LEFT(raw_text, 100) AS snippet, 
            1 - (embedding <=> %s::vector) AS similarity
        FROM trading_signals
        ORDER BY embedding <=> %s::vector 
        LIMIT 3;
    """, (query_vec, query_vec))

    results = cur.fetchall()
    
    print(f"--- Alpha Signals for: '{query_text}' ---")
    for row in results:
        print(f"[{row[0].upper()}] Score: {row[2]:.4f} | {row[1]}...")
        
except Exception as e:
    print(f"Query failed: {e}")


print("Top Signals Found:")
for row in cur.fetchall():
    print(f"[{row[0].upper()}] Sim: {row[2]:.4f} | {row[1][:80]}...")

conn.commit()
cur.close()
conn.close()
# Out:
# quant_secure_pass
# postgres://postgres:quant_secure_pass@localhost:5432/postgres
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2702.55it/s, Materializing param=pooler.dense.weight]
# --- Alpha Signals for: 'increased short interest in software stocks and AI margin compression' ---
# [MARKET] Score: 0.1951 | Market Regime for NVDA at 2026-02-27 15:59:00-05:00: Price 177.16...
# [MARKET] Score: 0.1951 | Market Regime for NVDA at 2026-02-27 15:59:00-05:00: Price 177.16...
# [SOCIAL] Score: 0.1215 | $BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT...
# Top Signals Found:
