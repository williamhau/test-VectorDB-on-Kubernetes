# %%
# %pip install -U cryptography langchain-text-splitters langchain-community langchain-chroma pypdf sentence-transformers langchain
# Out:
# Collecting cryptography
#   Using cached cryptography-46.0.5-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: langchain-text-splitters in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: langchain-community in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: langchain-chroma in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: pypdf in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (6.7.3)
# Requirement already satisfied: sentence-transformers in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (5.2.3)
# Requirement already satisfied: langchain in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (1.2.10)
# Collecting cffi>=2.0.0 (from cryptography)
#   Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.13 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-text-splitters) (1.2.16)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (2.0.47)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (0.7.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-chroma) (1.5.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (5.2.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: torch>=1.11.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain) (1.0.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Collecting pycparser (from cffi>=2.0.0->cryptography)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: build>=1.0.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.41.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.78.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: filelock in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: packaging>=20.9 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (26.0)
# Requirement already satisfied: shellingham in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: typer-slim in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.24.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: setuptools in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=1.11.0->sentence-transformers) (1.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.19)
# Requirement already satisfied: safetensors>=0.4.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: pyproject_hooks in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: anyio in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: flatbuffers in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.33.5)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.60b1)
# Requirement already satisfied: backoff>=1.10.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Using cached cryptography-46.0.5-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
# Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pycparser, cffi, cryptography
# Successfully installed cffi-2.0.0 cryptography-46.0.5 pycparser-3.0
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
# NEW PATH:
from langchain_text_splitters import RecursiveCharacterTextSplitter
# NEW PATH (Separate package for stability):
from langchain_chroma import Chroma 
# EMBEDDINGS (Ensure sentence-transformers is installed):
from langchain_community.embeddings import SentenceTransformerEmbeddings
# 1. Setup Data Pipeline Paths
PDF_PATH = "./data/2023-Equity-Derivatives-2023-Latham-Watkins.pdf"
CHROMA_PATH = "chroma_db_store"

def run_pipeline():
    # 2. Extract & Load: Efficiently read the PDF
    # PyPDFLoader handles large files by page
    loader = PyPDFLoader(PDF_PATH)
    raw_documents = loader.load()
    
    # 3. Transform: Chunking
    # RecursiveCharacterTextSplitter tries to keep paragraphs together
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000, 
        chunk_overlap=200,
        add_start_index=True
    )
    chunks = text_splitter.split_documents(raw_documents)
    print(f"Created {len(chunks)} chunks from {len(raw_documents)} pages.")

    # 4. Embed & Load: Inject into ChromaDB
    # Using a free, local embedding model (SentenceTransformer)
    embedding_func = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
    
    vector_db = Chroma.from_documents(
        documents=chunks, 
        embedding=embedding_func,
        persist_directory=CHROMA_PATH
    )
    print("Data successfully injected into ChromaDB.")
    return vector_db

def query_database(vector_db, query_text):
    # 5. Retrieve: Search for relevant data chunks
    results = vector_db.similarity_search(query_text, k=3)
    return results


if __name__ == "__main__":
    # Run the ingestion
    db = run_pipeline()
    
    # Example Query
    query = "What are the key derivative risks mentioned?"
    relevant_chunks = query_database(db, query)
    
    for i, chunk in enumerate(relevant_chunks):
        print(f"\n--- Relevant Chunk {i+1} (Page {chunk.metadata['page']}) ---")
        print(chunk.page_content[:300] + "...")
# Out:
# Created 463 chunks from 115 pages.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2435.81it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Data successfully injected into ChromaDB.
#
# --- Relevant Chunk 1 (Page 12) ---
# publicly available and that would be likely to significantly impact the price of the shares if it
# were to be made publicly available) or engage in the unlawful disclosure of inside information
# or market manipulation. If the counterparty to an OTC derivative transaction involving shares
# in an issu...
#
# --- Relevant Chunk 2 (Page 12) ---
# publicly available and that would be likely to significantly impact the price of the shares if it
# were to be made publicly available) or engage in the unlawful disclosure of inside information
# or market manipulation. If the counterparty to an OTC derivative transaction involving shares
# in an issu...
#
# --- Relevant Chunk 3 (Page 34) ---
# Risk
# 8 What types of risks do dealers face in the event of a bankruptcy or insolvency
# of the counterparty? Do any special bankruptcy or insolvency rules apply if the
# counterparty is the issuer or an affiliate of the issuer?
# The risk that dealers face in the event of the bankruptcy or insolvency of...
