# %%
# %pip install qdrant-client langchain-qdrant qdrant-client pypdf sentence-transformers
# Out:
# Requirement already satisfied: qdrant-client in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (1.17.0)
# Collecting langchain-qdrant
#   Downloading langchain_qdrant-1.1.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pypdf in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (6.7.3)
# Requirement already satisfied: sentence-transformers in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (5.2.3)
# Requirement already satisfied: grpcio>=1.41.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from qdrant-client) (1.78.1)
# Requirement already satisfied: httpx>=0.20.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from qdrant-client) (2.4.2)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from qdrant-client) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from qdrant-client) (6.33.5)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from qdrant-client) (2.12.5)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from qdrant-client) (2.6.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-qdrant) (1.2.16)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (5.2.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: torch>=1.11.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: anyio in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.12.1)
# Requirement already satisfied: certifi in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: idna in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.3.0)
# Requirement already satisfied: filelock in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: packaging>=20.9 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: shellingham in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: typer-slim in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.24.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.7.7)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.4.2)
# Requirement already satisfied: setuptools in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=1.11.0->sentence-transformers) (1.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.19)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (0.25.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: typer>=0.24.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-qdrant) (3.4.4)
# Requirement already satisfied: click>=8.2.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.20.0->sentence-transformers) (0.1.2)
# Downloading langchain_qdrant-1.1.0-py3-none-any.whl (24 kB)
# Installing collected packages: langchain-qdrant
# Successfully installed langchain-qdrant-1.1.0
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from qdrant_client import QdrantClient
client = QdrantClient(url="http://localhost:6333")

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http import models
from langchain_community.embeddings import SentenceTransformerEmbeddings

# 1. Configuration (Matches your Docker Compose)
QDRANT_URL = "http://localhost:6333"
COLLECTION_NAME = "equity_research_reports"

def run_qdrant_pipeline(pdf_path):
    # 2. Load and Chunk PDF
    loader = PyPDFLoader(pdf_path)
    raw_docs = loader.load()
    
    # Using specific headers to simulate "Equity Framework" structure
    splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=80)
    chunks = splitter.split_documents(raw_docs)

    # 3. Initialize Embedding Model (Local MiniLM)
    embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

    # 4. Ingest into Qdrant
    # .from_documents handles collection creation and indexing automatically
    vector_store = QdrantVectorStore.from_documents(
        documents=chunks,
        embedding=embeddings,
        url=QDRANT_URL,
        collection_name=COLLECTION_NAME,
        force_recreate=False # Set to True if you want to wipe the DB and restart
    )
    
    print(f"Ingested {len(chunks)} chunks into Qdrant collection: {COLLECTION_NAME}")
    return vector_store

def query_qdrant(query_text):
    embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
    
    # Initialize client for specific retrieval
    client = QdrantClient(url=QDRANT_URL)
    
    vector_store = QdrantVectorStore(
        client=client,
        collection_name=COLLECTION_NAME,
        embedding=embeddings, 
    )
    
    # 5. Semantic Search
    results = vector_store.similarity_search(query_text, k=3)
    return results

if __name__ == "__main__":
    PDF_FILE = "./data/2023-Equity-Derivatives-2023-Latham-Watkins.pdf"
    
    if os.path.exists(PDF_FILE):
        # Step 1: Data Ingestion
        run_qdrant_pipeline(PDF_FILE)
        
        # Step 2: Querying
        user_query = "What is the outlook for equity derivatives?"
        matches = query_qdrant(user_query)
        
        for i, doc in enumerate(matches):
            page_num = doc.metadata.get('page', 'Unknown')
            print(f"\n--- Result {i+1} (Page {page_num}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print(f"Please place {PDF_FILE} in the project directory.")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2996.06it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Ingested 510 chunks into Qdrant collection: equity_research_reports
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2596.23it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# --- Result 1 (Page 69) ---
# accounting, cash flow, corporate or regulatory perspective.
# Typical equity derivatives products that allow a shareholder to acquire a substantial position
# in a publicly traded equity or to monetise or hedge an existing equity position include the
# following:
# • margin loans allow a borrower to finan...
#
# --- Result 2 (Page 69) ---
# accounting, cash flow, corporate or regulatory perspective.
# Typical equity derivatives products that allow a shareholder to acquire a substantial position
# in a publicly traded equity or to monetise or hedge an existing equity position include the
# following:
# • margin loans allow a borrower to finan...
#
# --- Result 3 (Page 69) ---
# accounting, cash flow, corporate or regulatory perspective.
# Typical equity derivatives products that allow a shareholder to acquire a substantial position
# in a publicly traded equity or to monetise or hedge an existing equity position include the
# following:
# • margin loans allow a borrower to finan...
